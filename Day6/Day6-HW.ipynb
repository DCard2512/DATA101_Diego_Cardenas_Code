# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 6
# ---------------------------------------
#
# GOALS:
#
# 1. Answer all the questions from the lecture.
# 2. Practice wrangling data - doing more advanced code
# 3. Complete your first more advanced Exploration/Exercise
#
# ----------------------------------------------------------
#
# This homework has **4 Questions** and **7 Exercises**
#
# NOTE:
# Exercises will tend to be an analysis of a single piece of data where one exercise builds on the next.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
file_location = 'https://joannabieri.com/introdatascience/data/hotels.csv'
DF_raw_hotels = pd.read_csv(file_location)

# %%
show(DF_raw_hotels)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_2c5224c9_5cae_42c8_ba54_f83d55b8b3b5"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_2c5224c9_5cae_42c8_ba54_f83d55b8b3b5:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 119,390x32 to 255x32 as maxBytes=64KB", "filtered_row_count": 119135, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>hotel</th>\n      <th>is_canceled</th>\n      <th>lead_time</th>\n      <th>arrival_date_year</th>\n      <th>arrival_date_month</th>\n      <th>arrival_date_week_number</th>\n      <th>arrival_date_day_of_month</th>\n      <th>stays_in_weekend_nights</th>\n      <th>stays_in_week_nights</th>\n      <th>adults</th>\n      <th>children</th>\n      <th>babies</th>\n      <th>meal</th>\n      <th>country</th>\n      <th>market_segment</th>\n      <th>distribution_channel</th>\n      <th>is_repeated_guest</th>\n      <th>previous_cancellations</th>\n      <th>previous_bookings_not_canceled</th>\n      <th>reserved_room_type</th>\n      <th>assigned_room_type</th>\n      <th>booking_changes</th>\n      <th>deposit_type</th>\n      <th>agent</th>\n      <th>company</th>\n      <th>days_in_waiting_list</th>\n      <th>customer_type</th>\n      <th>adr</th>\n      <th>required_car_parking_spaces</th>\n      <th>total_of_special_requests</th>\n      <th>reservation_status</th>\n      <th>reservation_status_date</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Resort Hotel\", 0, 342, 2015, \"July\", 27, 1, 0, 0, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 3, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 0.0, 0, 0, \"Check-Out\", \"2015-07-01\"], [\"Resort Hotel\", 0, 737, 2015, \"July\", 27, 1, 0, 0, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 4, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 0.0, 0, 0, \"Check-Out\", \"2015-07-01\"], [\"Resort Hotel\", 0, 7, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Direct\", \"Direct\", 0, 0, 0, \"A\", \"C\", 0, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\"], [\"Resort Hotel\", 0, 13, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Corporate\", \"Corporate\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 304.0, \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\"], [\"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\"], [\"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\"], [\"Resort Hotel\", 0, 0, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 0, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 107.0, 0, 0, \"Check-Out\", \"2015-07-03\"], [\"Resort Hotel\", 0, 9, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"FB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 0, \"No Deposit\", 303.0, \"___NaN___\", 0, \"Transient\", 103.0, 0, 1, \"Check-Out\", \"2015-07-03\"], [\"Resort Hotel\", 1, 85, 2015, \"July\", 27, 1, 0, 3, 2, 0.0, 0, \"BB\", \"PRT\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 82.0, 0, 1, \"Canceled\", \"2015-05-06\"], [\"Resort Hotel\", 1, 75, 2015, \"July\", 27, 1, 0, 3, 2, 0.0, 0, \"HB\", \"PRT\", \"Offline TA/TO\", \"TA/TO\", 0, 0, 0, \"D\", \"D\", 0, \"No Deposit\", 15.0, \"___NaN___\", 0, \"Transient\", 105.5, 0, 0, \"Canc ...

# %%
# I always look at the column names - they have to be spelled exactly!
columns_list = list(DF_raw_hotels.keys())
print(columns_list)
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %% [markdown]
# ### Example of Combining Masks
#
# * Show only results for visitors from USA or GBR.

# %%
mask = (DF_raw_hotels['country']=='USA') | (DF_raw_hotels['country']=='GBR')
show(DF_raw_hotels[mask])
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_b6b54efb_b584_4f23_9835_4929809aea1d"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_b6b54efb_b584_4f23_9835_4929809aea1d:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "order": [], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 14,226x32 to 256x32 as maxBytes=64KB", "filtered_row_count": 13970, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>hotel</th>\n      <th>is_canceled</th>\n      <th>lead_time</th>\n      <th>arrival_date_year</th>\n      <th>arrival_date_month</th>\n      <th>arrival_date_week_number</th>\n      <th>arrival_date_day_of_month</th>\n      <th>stays_in_weekend_nights</th>\n      <th>stays_in_week_nights</th>\n      <th>adults</th>\n      <th>children</th>\n      <th>babies</th>\n      <th>meal</th>\n      <th>country</th>\n      <th>market_segment</th>\n      <th>distribution_channel</th>\n      <th>is_repeated_guest</th>\n      <th>previous_cancellations</th>\n      <th>previous_bookings_not_canceled</th>\n      <th>reserved_room_type</th>\n      <th>assigned_room_type</th>\n      <th>booking_changes</th>\n      <th>deposit_type</th>\n      <th>agent</th>\n      <th>company</th>\n      <th>days_in_waiting_list</th>\n      <th>customer_type</th>\n      <th>adr</th>\n      <th>required_car_parking_spaces</th>\n      <th>total_of_special_requests</th>\n      <th>reservation_status</th>\n      <th>reservation_status_date</th>\n    </tr>\n  </thead></table>", "data_json": "[[2, \"Resort Hotel\", 0, 7, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Direct\", \"Direct\", 0, 0, 0, \"A\", \"C\", 0, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\"], [3, \"Resort Hotel\", 0, 13, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Corporate\", \"Corporate\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 304.0, \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\"], [4, \"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\"], [5, \"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\"], [12, \"Resort Hotel\", 0, 68, 2015, \"July\", 27, 1, 0, 4, 2, 0.0, 0, \"BB\", \"USA\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"D\", \"E\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 97.0, 0, 3, \"Check-Out\", \"2015-07-05\"], [19, \"Resort Hotel\", 0, 7, 2015, \"July\", 27, 1, 0, 4, 2, 0.0, 0, \"BB\", \"GBR\", \"Direct\", \"Direct\", 0, 0, 0, \"G\", \"G\", 0, \"No Deposit\", 250.0, \"___NaN___\", 0, \"Transient\", 153.0, 0, 1, \"Check-Out\", \"2015-07-05\"], [20, \"Resort Hotel\", 0, 37, 2015, \"July\", 27, 1, 1, 4, 1, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"F\", \"F\", 0, \"No Deposit\", 241.0, \"___NaN___\", 0, \"Transient\", 97.29, 0, 1, \"Check-Out\", \"2015-07-06\"], [24, \"Resort Hotel\", 0, 127, 2015, \"July\", 27, 1, 2, 5, 2, 0.0, 0, \"HB\", \"GBR\", \"Offline TA/TO\", \"TA/TO\", 0, 0, 0, \"D\", \"I\", 0, \"No Deposit\", 115.0, \"___NaN___\", 0, \"Contract\", 94.95, 0, 1, \"Check-Out\", \"2015-07-01\"], [31, \"Resort Hotel\", 0, 95, 2015, \"July\", 27, 1, 4, 11, 2, 0.0, 0, \"BB\", \"GBR\", \"Offline TA/TO\", \"TA/TO\", 0, 0, 0, \"D\", \"D\", 0, \"No Deposit\", 241.0, \"___NaN___\", 0, \"Transient\", 63.86, 0, 0, \"Check-Out\", \"2015-07-16\"], [48, \"Resort Hotel\", 0, 90, 2015, \"July\", 27, 2, 2, 5, 2, 0.0, 0, \"HB\", \"GBR\", \"Offline TA/TO\", \"TA/TO\", 0, 0, 0, \"A\", \"B\", 1, \"No Deposit\", 243.0, \"___NaN___\" ...

# %% [markdown]
# ## Example Finding unique values

# %%
my_columns = ['market_segment','customer_type']
DF_raw_hotels[my_columns].drop_duplicates()
# Out:
#        market_segment    customer_type
# 0              Direct        Transient
# 3           Corporate        Transient
# 4           Online TA        Transient
# 9       Offline TA/TO        Transient
# 16      Offline TA/TO         Contract
# 47      Offline TA/TO  Transient-Party
# 125     Complementary        Transient
# 127         Online TA  Transient-Party
# 260            Direct  Transient-Party
# 413            Groups  Transient-Party
# 417            Groups        Transient
# 539         Online TA            Group
# 1530        Corporate  Transient-Party
# 1539           Direct            Group
# 1587    Offline TA/TO            Group
# 2262        Corporate         Contract
# 2263           Direct         Contract
# 2698           Groups         Contract
# 9511    Complementary  Transient-Party
# 14051   Complementary            Group
# 14654          Groups            Group
# 15141       Corporate            Group
# 15261   Complementary         Contract
# 15506       Online TA         Contract
# 40600       Undefined  Transient-Party
# 49013        Aviation  Transient-Party
# 49372        Aviation        Transient
# 112102       Aviation            Group

# %% [markdown]
# ## Example Counting unique values

# %%
my_columns = ['market_segment']
DF_raw_hotels[my_columns].value_counts()
# Out:
# market_segment
# Online TA         56477
# Offline TA/TO     24219
# Groups            19811
# Direct            12606
# Corporate          5295
# Complementary       743
# Aviation            237
# Undefined             2
# Name: count, dtype: int64

# %% [markdown]
# ## Example of Counting unique values in two columns - unsorted

# %%
my_columns = ['market_segment','customer_type']
DF_raw_hotels[my_columns].value_counts(sort=False)
# Out:
# market_segment  customer_type
# Aviation        Group                  2
#                 Transient            218
#                 Transient-Party       17
# Complementary   Contract               2
#                 Group                  6
#                 Transient            703
#                 Transient-Party       32
# Corporate       Contract              22
#                 Group                 29
#                 Transient           3576
#                 Transient-Party     1668
# Direct          Contract              14
#                 Group                134
#                 Transient          11336
#                 Transient-Party     1122
# Groups          Contract             735
#                 Group                 16
#                 Transient           8427
#                 Transient-Party    10633
# Offline TA/TO   Contract            1817
#                 Group                211
#                 Transient          14054
#                 Transient-Party     8137
# Online TA       Contract            1486
#                 Group                179
#                 Transient          51299
#                 Transient-Party     3513
# Undefined       Transient-Party        2
# Name: count, dtype: int64

# %% [markdown]
# ## Example of Saving Unique Values to a Data Frame
#
# Just add the command **.reset_index().rename(columns={"index": "value", 0: "count"})**. In this class

# %%
my_columns = ['market_segment','customer_type']
my_counts = DF_raw_hotels[my_columns].value_counts()
my_counts = my_counts.reset_index().rename(columns={"index": "value", 0: "count"})
show(my_counts)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5cf5fed1_b9a9_42f6_b2e4_e2217f193c55"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5cf5fed1_b9a9_42f6_b2e4_e2217f193c55:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>market_segment</th>\n      <th>customer_type</th>\n      <th>count</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Online TA\", \"Transient\", 51299], [\"Offline TA/TO\", \"Transient\", 14054], [\"Direct\", \"Transient\", 11336], [\"Groups\", \"Transient-Party\", 10633], [\"Groups\", \"Transient\", 8427], [\"Offline TA/TO\", \"Transient-Party\", 8137], [\"Corporate\", \"Transient\", 3576], [\"Online TA\", \"Transient-Party\", 3513], [\"Offline TA/TO\", \"Contract\", 1817], [\"Corporate\", \"Transient-Party\", 1668], [\"Online TA\", \"Contract\", 1486], [\"Direct\", \"Transient-Party\", 1122], [\"Groups\", \"Contract\", 735], [\"Complementary\", \"Transient\", 703], [\"Aviation\", \"Transient\", 218], [\"Offline TA/TO\", \"Group\", 211], [\"Online TA\", \"Group\", 179], [\"Direct\", \"Group\", 134], [\"Complementary\", \"Transient-Party\", 32], [\"Corporate\", \"Group\", 29], [\"Corporate\", \"Contract\", 22], [\"Aviation\", \"Transient-Party\", 17], [\"Groups\", \"Group\", 16], [\"Direct\", \"Contract\", 14], [\"Complementary\", \"Group\", 6], [\"Aviation\", \"Group\", 2], [\"Complementary\", \"Contract\", 2], [\"Undefined\", \"Transient-Party\", 2]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ## Example of Adding a column to a Data Frame

# %%
DF_raw_hotels['little_ones'] = DF_raw_hotels['children'] + DF_raw_hotels['babies']
show(DF_raw_hotels)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4295bef1_ddd7_463e_a871_e366d0dbff57"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4295bef1_ddd7_463e_a871_e366d0dbff57:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 119,390x34 to 240x34 as maxBytes=64KB", "filtered_row_count": 119150, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>hotel</th>\n      <th>is_canceled</th>\n      <th>lead_time</th>\n      <th>arrival_date_year</th>\n      <th>arrival_date_month</th>\n      <th>arrival_date_week_number</th>\n      <th>arrival_date_day_of_month</th>\n      <th>stays_in_weekend_nights</th>\n      <th>stays_in_week_nights</th>\n      <th>adults</th>\n      <th>children</th>\n      <th>babies</th>\n      <th>meal</th>\n      <th>country</th>\n      <th>market_segment</th>\n      <th>distribution_channel</th>\n      <th>is_repeated_guest</th>\n      <th>previous_cancellations</th>\n      <th>previous_bookings_not_canceled</th>\n      <th>reserved_room_type</th>\n      <th>assigned_room_type</th>\n      <th>booking_changes</th>\n      <th>deposit_type</th>\n      <th>agent</th>\n      <th>company</th>\n      <th>days_in_waiting_list</th>\n      <th>customer_type</th>\n      <th>adr</th>\n      <th>required_car_parking_spaces</th>\n      <th>total_of_special_requests</th>\n      <th>reservation_status</th>\n      <th>reservation_status_date</th>\n      <th>kids</th>\n      <th>little_ones</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Resort Hotel\", 0, 342, 2015, \"July\", 27, 1, 0, 0, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 3, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 0.0, 0, 0, \"Check-Out\", \"2015-07-01\", 0.0, 0.0], [\"Resort Hotel\", 0, 737, 2015, \"July\", 27, 1, 0, 0, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 4, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 0.0, 0, 0, \"Check-Out\", \"2015-07-01\", 0.0, 0.0], [\"Resort Hotel\", 0, 7, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Direct\", \"Direct\", 0, 0, 0, \"A\", \"C\", 0, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\", 0.0, 0.0], [\"Resort Hotel\", 0, 13, 2015, \"July\", 27, 1, 0, 1, 1, 0.0, 0, \"BB\", \"GBR\", \"Corporate\", \"Corporate\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 304.0, \"___NaN___\", 0, \"Transient\", 75.0, 0, 0, \"Check-Out\", \"2015-07-02\", 0.0, 0.0], [\"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\", 0.0, 0.0], [\"Resort Hotel\", 0, 14, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"GBR\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 98.0, 0, 1, \"Check-Out\", \"2015-07-03\", 0.0, 0.0], [\"Resort Hotel\", 0, 0, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"BB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 0, \"No Deposit\", \"___NaN___\", \"___NaN___\", 0, \"Transient\", 107.0, 0, 0, \"Check-Out\", \"2015-07-03\", 0.0, 0.0], [\"Resort Hotel\", 0, 9, 2015, \"July\", 27, 1, 0, 2, 2, 0.0, 0, \"FB\", \"PRT\", \"Direct\", \"Direct\", 0, 0, 0, \"C\", \"C\", 0, \"No Deposit\", 303.0, \"___NaN___\", 0, \"Transient\", 103.0, 0, 1, \"Check-Out\", \"2015-07-03\", 0.0, 0.0], [\"Resort Hotel\", 1, 85, 2015, \"July\", 27, 1, 0, 3, 2, 0.0, 0, \"BB\", \"PRT\", \"Online TA\", \"TA/TO\", 0, 0, 0, \"A\", \"A\", 0, \"No Deposit\", 240.0, \"___NaN___\", 0, \"Transient\", 82.0, 0, 1, \"Canceled\", \"2015-05-06\", 0.0, 0.0], [\"Resort Hotel\", 1, 75, 2015, \"July\", 27, 1, 0, 3, 2, 0.0, 0, \"HB\",  ...

# %% [markdown]
# **Q1** Count up the number of little_ones in different hotel types (Hint - use value_counts() with hotel and little_ones as your columns.)

# %%
# Your code here:
my_col = ['hotel', 'little_ones'] 
my_count = DF_raw_hotels[my_col].value_counts()
show(my_count)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_48aad3da_bd8d_47c8_9a62_e899eaf0fb3e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_48aad3da_bd8d_47c8_9a62_e899eaf0fb3e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>hotel</th>\n      <th>little_ones</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"City Hotel\", 0.0, 73923], [\"Resort Hotel\", 0.0, 36131], [\"City Hotel\", 1.0, 3263], [\"Resort Hotel\", 1.0, 2183], [\"City Hotel\", 2.0, 2056], [\"Resort Hotel\", 2.0, 1716], [\"City Hotel\", 3.0, 82], [\"Resort Hotel\", 3.0, 29], [\"City Hotel\", 9.0, 1], [\"City Hotel\", 10.0, 1], [\"Resort Hotel\", 10.0, 1]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# **Q2** Add a new column that calculates the total number of humans (all_humans) in the room (adults+children+babies) (Hint - you can copy and paste the code above where we calculated little_ones and add on another thing)

# %%
DF_raw_hotels['all_humans'] = DF_raw_hotels['adults'] + DF_raw_hotels['children'] + DF_raw_hotels['babies'] 
my_col = ['hotel', 'all_humans'] 
my_count = DF_raw_hotels[my_col].value_counts()
show(my_count)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_93544656_d4c2_4133_a1d6_4df3ac1f3f1a"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_93544656_d4c2_4133_a1d6_4df3ac1f3f1a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>hotel</th>\n      <th>all_humans</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"City Hotel\", 2.0, 53932], [\"Resort Hotel\", 2.0, 28116], [\"City Hotel\", 1.0, 15568], [\"City Hotel\", 3.0, 7705], [\"Resort Hotel\", 1.0, 7013], [\"Resort Hotel\", 3.0, 2789], [\"Resort Hotel\", 4.0, 2069], [\"City Hotel\", 4.0, 1860], [\"City Hotel\", 0.0, 167], [\"City Hotel\", 5.0, 92], [\"Resort Hotel\", 5.0, 45], [\"Resort Hotel\", 0.0, 13], [\"Resort Hotel\", 26.0, 5], [\"Resort Hotel\", 20.0, 2], [\"Resort Hotel\", 27.0, 2], [\"City Hotel\", 12.0, 1], [\"City Hotel\", 10.0, 1], [\"Resort Hotel\", 6.0, 1], [\"Resort Hotel\", 10.0, 1], [\"Resort Hotel\", 12.0, 1], [\"Resort Hotel\", 40.0, 1], [\"Resort Hotel\", 50.0, 1], [\"Resort Hotel\", 55.0, 1]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# **Q3** Can you figure out what the code below is doing - comment on each line -- remember you can add a comment using the hashtag #

# %%
# PLEASE ADD YOUR COMMENTS!
DF_raw_hotels['little_ones'] = DF_raw_hotels['children'] + DF_raw_hotels['babies'] #condenses children and baby columns to one called little_ones
my_columns = ['hotel','little_ones'] #Has a set of columns that we will want to see which are only hotel and new column little_ones
my_counts = DF_raw_hotels[my_columns].value_counts() #Counts the values in the columns we decided to choose
my_counts = my_counts.reset_index().rename(columns={"index": "value", 0: "count"}) #We are making it look nicer
my_counts['proportion']=my_counts['count']/sum(my_counts['count']) #we make a new column that we are looking for a proportion
show(my_counts) #Nicely make a list of our data
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ad1a73ba_1597_45d2_9fd7_0923eb6e3e29"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ad1a73ba_1597_45d2_9fd7_0923eb6e3e29:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>hotel</th>\n      <th>little_ones</th>\n      <th>count</th>\n      <th>proportion</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"City Hotel\", 0.0, 73923, 0.619193], [\"Resort Hotel\", 0.0, 36131, 0.30264], [\"City Hotel\", 1.0, 3263, 0.027332], [\"Resort Hotel\", 1.0, 2183, 0.018285], [\"City Hotel\", 2.0, 2056, 0.017221], [\"Resort Hotel\", 2.0, 1716, 0.014374], [\"City Hotel\", 3.0, 82, 0.000687], [\"Resort Hotel\", 3.0, 29, 0.000243], [\"City Hotel\", 9.0, 1, 8e-06], [\"City Hotel\", 10.0, 1, 8e-06], [\"Resort Hotel\", 10.0, 1, 8e-06]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ## Example of Grouping the data frame into chunks

# %%
my_columns = ['adults','children','little_ones','babies']
DF_raw_hotels.groupby(by=['hotel'])[my_columns].sum()
# Out:
#               adults  children  little_ones  babies
# hotel
# City Hotel    146838    7248.0       7640.0     392
# Resort Hotel   74798    5155.0       5712.0     557

# %% [markdown]
# There are lots of different operaitons you could use:
#
# * .min()
# * .max()
# * .mean()
# * .median()
# * .sum()
# * .prod()
# * .count()
# * .describe()

# %% [markdown]
# Here we see that .describe() does all the descriptive statistics for each of columns, broken into the two groups.
#
# ## Example of Grouping to quickly generate data
#
# The .groupby() function lets you quickly generate data about things you care about. In just one command below we are able to look at the total number of occupants for each of the columns (adults, children, little_ones, and babies) for each month in the data set.

# %%
DF_raw_hotels.groupby(by=['arrival_date_month'])[my_columns].sum()
# Out:
#                     adults  children  little_ones  babies
# arrival_date_month
# April                20806    1141.0       1194.0      53
# August               27795    2780.0       2976.0     196
# December             12382     736.0        814.0      78
# February             14450     790.0        849.0      59
# January              10024     452.0        500.0      48
# July                 25164    2322.0       2443.0     121
# June                 20353    1057.0       1128.0      71
# March                17675     700.0        757.0      57
# May                  21539     845.0        917.0      72
# November             11488     279.0        324.0      45
# October              20279     703.0        765.0      62
# September            19681     598.0        685.0      87

# %% [markdown]
# **Q4** Try changing the code above to calculate the mean, max, and min for the above data.

# %%
DF_raw_hotels.groupby(by=['arrival_date_month'])[my_columns].min()
# Out:
#                     adults  children  little_ones  babies
# arrival_date_month
# April                    0       0.0          0.0       0
# August                   0       0.0          0.0       0
# December                 0       0.0          0.0       0
# February                 0       0.0          0.0       0
# January                  0       0.0          0.0       0
# July                     0       0.0          0.0       0
# June                     0       0.0          0.0       0
# March                    0       0.0          0.0       0
# May                      0       0.0          0.0       0
# November                 0       0.0          0.0       0
# October                  0       0.0          0.0       0
# September                0       0.0          0.0       0

# %% [markdown]
# # Exercises:

# %% [markdown]
# ## Our first big-ish problem:
#
# Now you will try to use our hotels data set to answer some questions! You will need to use the tools we have learned so far to look into the data and try to answer the questions. Really try to answer the questions with as few hints as possible!
#
# ### IF YOU USE MY ANSWER - avoid plagiarism
#
# To avoid plagiarism, if you end up copying my answer and using it, YOU MUST explain clearly what each part of the code is doing. It's okay to need to use my code at this point, but it is not helpful to your learning to blindly copy and paste without trying to understand.
#
# **Hints and Answers can be found in the lecture notes!**
#
# ### Exercise 1
#
# Are people traveling on a whim?
#
# How could you find out?
#
# Try creating a mask filtering for hotel bookings where the guest is **not** from the US (`country` code `"USA"`) and the `lead_time` is less than 1 day.
#
# What proportion of people traveled last minute?

# %%
my_columns = ['hotel', 'country', 'lead_time']
mask = (DF_raw_hotels['country']!= "USA") & (DF_raw_hotels['lead_time'] < 1)
DF_mask = DF_raw_hotels[mask]
show(DF_mask[my_columns].value_counts())
len(DF_mask) / len(DF_raw_hotels)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4cbaf0ad_505d_48fb_8373_c23ee075e713"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4cbaf0ad_505d_48fb_8373_c23ee075e713:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>hotel</th>\n      <th>country</th>\n      <th>lead_time</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Resort Hotel\", \"PRT\", 0, 1972], [\"City Hotel\", \"PRT\", 0, 1738], [\"Resort Hotel\", \"ESP\", 0, 270], [\"City Hotel\", \"FRA\", 0, 240], [\"Resort Hotel\", \"GBR\", 0, 172], [\"City Hotel\", \"ESP\", 0, 153], [\"Resort Hotel\", \"FRA\", 0, 149], [\"City Hotel\", \"DEU\", 0, 104], [\"City Hotel\", \"GBR\", 0, 89], [\"City Hotel\", \"ITA\", 0, 70], [\"City Hotel\", \"BRA\", 0, 62], [\"Resort Hotel\", \"DEU\", 0, 55], [\"Resort Hotel\", \"ITA\", 0, 51], [\"City Hotel\", \"AGO\", 0, 50], [\"Resort Hotel\", \"NLD\", 0, 46], [\"City Hotel\", \"CHN\", 0, 43], [\"City Hotel\", \"BEL\", 0, 41], [\"Resort Hotel\", \"CN\", 0, 40], [\"City Hotel\", \"NLD\", 0, 33], [\"Resort Hotel\", \"BRA\", 0, 31], [\"Resort Hotel\", \"CHE\", 0, 31], [\"Resort Hotel\", \"CHN\", 0, 31], [\"Resort Hotel\", \"IRL\", 0, 30], [\"City Hotel\", \"SWE\", 0, 26], [\"City Hotel\", \"AUS\", 0, 24], [\"Resort Hotel\", \"SWE\", 0, 23], [\"City Hotel\", \"CHE\", 0, 22], [\"City Hotel\", \"RUS\", 0, 21], [\"Resort Hotel\", \"BEL\", 0, 21], [\"City Hotel\", \"POL\", 0, 20], [\"City Hotel\", \"IRL\", 0, 18], [\"Resort Hotel\", \"FIN\", 0, 16], [\"City Hotel\", \"CN\", 0, 16], [\"City Hotel\", \"AUT\", 0, 13], [\"City Hotel\", \"ISR\", 0, 13], [\"City Hotel\", \"TUR\", 0, 11], [\"Resort Hotel\", \"AUS\", 0, 11], [\"Resort Hotel\", \"POL\", 0, 11], [\"City Hotel\", \"HRV\", 0, 11], [\"Resort Hotel\", \"AGO\", 0, 11], [\"City Hotel\", \"DNK\", 0, 10], [\"City Hotel\", \"MAR\", 0, 9], [\"City Hotel\", \"MOZ\", 0, 9], [\"Resort Hotel\", \"MAR\", 0, 8], [\"City Hotel\", \"ROU\", 0, 8], [\"Resort Hotel\", \"RUS\", 0, 8], [\"City Hotel\", \"JPN\", 0, 7], [\"Resort Hotel\", \"ARG\", 0, 7], [\"City Hotel\", \"MEX\", 0, 7], [\"City Hotel\", \"GRC\", 0, 7], [\"City Hotel\", \"TUN\", 0, 6], [\"City Hotel\", \"CHL\", 0, 6], [\"City Hotel\", \"ARG\", 0, 6], [\"City Hotel\", \"LUX\", 0, 6], [\"City Hotel\", \"CZE\", 0, 6], [\"City Hotel\", \"KOR\", 0, 5], [\"City Hotel\", \"IRQ\", 0, 5], [\"Resort Hotel\", \"AUT\", 0, 5], [\"City Hotel\", \"NOR\", 0, 5], [\"City Hotel\", \"UKR\", 0, 4], [\"City Hotel\", \"CRI\", 0, 4], [\"Resort Hotel\", \"DNK\", 0, 4], [\"Resort Hotel\", \"UKR\", 0, 4], [\"City Hotel\", \"DZA\", 0, 4], [\"City Hotel\", \"NZL\", 0, 4], [\"City Hotel\", \"GNB\", 0, 4], [\"City Hotel\", \"SRB\", 0, 3], [\"City Hotel\", \"FIN\", 0, 3], [\"City Hotel\", \"HUN\", 0, 3], [\"City Hotel\", \"ZAF\", 0, 3], [\"Resort Hotel\", \"LTU\", 0, 3], [\"City Hotel\", \"LBY\", 0, 3], [\"Resort Hotel\", \"NOR\", 0, 3], [\"Resort Hotel\", \"LUX\", 0, 3], [\"Resort Hotel\", \"HUN\", 0, 3], [\"Resort Hotel\", \"ROU\", 0, 3], [\"City Hotel\", \"COL\", 0, 3], [\"Resort Hotel\", \"TUR\", 0, 3], [\"Resort Hotel\", \"LBN\", 0, 2], [\"Resort Hotel\", \"JPN\", 0, 2], [\"City Hotel\", \"NGA\", 0, 2], [\"Resort Hotel\", \"ISR\", 0, 2], [\"City Hotel\", \"VEN\", 0, 2], [\"City Hotel\", \"SVN\", 0, 2], [\"City Hotel\", \"STP\", 0, 2], [\"City Hotel\", \"SAU\", 0, 2], [\"City Hotel\", \"AZE\", 0, 2], [\"City Hotel\", \"IND\", 0, 2], [\"City Hotel\", \"EST\", 0, 2], [\"City Hotel\", \"ECU\", 0, 2], [\"City Hotel\", \"CYP\", 0, 2], [\"Resort Hotel\", \"ISL\", 0, 1], [\"Resort Hotel\", \"NZL\", 0, 1], [\"Resort Hotel\", \"JAM\", 0, 1], [\"Resort Hotel\", \"JOR\", 0, 1], [\"Resort Hotel\", \"KAZ\", 0, 1], [\"Resort Hotel\", \"LVA\", 0, 1], [\"Resort Hotel\", \"MDG\", 0, 1], [\"Resort Hotel\", \"NGA\", ...
# 0.05171287377502303

# %% [markdown]
# ### Exercise 2
#
# How many bookings involve at least 1 child **or** baby?

# %%
# Your code here:
my_col = ['children', 'babies']
mask = (DF_raw_hotels['children'] > 1) | (DF_raw_hotels['babies'] > 1)
DF_mask = DF_raw_hotels[mask]
show(DF_mask[my_col].sum())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_2231401e_095a_4851_be04_cf332e8957db"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_2231401e_095a_4851_be04_cf332e8957db:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"children\", 7545.0], [\"babies\", 81.0]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### Exercise 3
#
# Do you think it's more likely to find bookings with children or babies in city hotels or resort hotels?
# Test your intuition.

# %%
kids = DF_raw_hotels.groupby('hotel')[['children','babies']].sum() #we are grouping together by hotel and getting the sum of children and babies
kids = kids.reset_index().rename(columns={"index": "value", 0: "count"}) #we rename the columns so we get the sum
show(kids) #display the table
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_bfb128c2_3994_4d55_8e03_f19a4c62096c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_bfb128c2_3994_4d55_8e03_f19a4c62096c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>hotel</th>\n      <th>children</th>\n      <th>babies</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"City Hotel\", 7248.0, 392], [\"Resort Hotel\", 5155.0, 557]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### Exercise 4
#
# Create a frequency table of the number of `adults` in a booking.
# Display the results in descending order so the most common observation is on top.
# What is the most common number of adults in bookings in this dataset?
# Are there any surprising results?

# %%
adults = DF_raw_hotels['adults'].value_counts()
adults = adults.reset_index().rename(columns={"index": "value", 0: "count"})
show(adults)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_de283f8e_d48c_4a75_9ec5_63efe45fcc3e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_de283f8e_d48c_4a75_9ec5_63efe45fcc3e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>adults</th>\n      <th>count</th>\n    </tr>\n  </thead></table>", "data_json": "[[2, 89680], [1, 23027], [3, 6202], [0, 403], [4, 62], [26, 5], [27, 2], [20, 2], [5, 2], [40, 1], [50, 1], [55, 1], [6, 1], [10, 1]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### Exercise 5
#
# Repeat Exercise 5, once for canceled bookings (`is_canceled` coded as 1) and once for not canceled bookings (`is_canceled` coded as 0).
# What does this reveal about the surprising results you spotted in the previous exercise?

# %%
adults_canceled = DF_raw_hotels.groupby('is_canceled')['adults'].value_counts()
adults_canceled = adults_canceled.reset_index().rename(columns={"index": "value", 0: "count"})
adults_canceled
# Out:
#     is_canceled  adults  count
# 0             0       2  54422
# 1             0       1  16353
# 2             0       3   4051
# 3             0       0    294
# 4             0       4     46
# 5             1       2  35258
# 6             1       1   6674
# 7             1       3   2151
# 8             1       0    109
# 9             1       4     16
# 10            1      26      5
# 11            1       5      2
# 12            1      20      2
# 13            1      27      2
# 14            1       6      1
# 15            1      10      1
# 16            1      40      1
# 17            1      50      1
# 18            1      55      1

# %% [markdown]
# ### Exercise 6
#
# Calculate minimum, mean, median, and maximum average daily rate (column labeled 'adr') grouped by `hotel` type so that you can get these statistics separately for resort and city hotels. (Hint - try using .describe() after doing group by)
#
# Which type of hotel is higher, on average?

# %%
DF_raw_hotels.groupby('hotel')['adr'].describe()
# Out:
#                 count        mean        std   min   25%   50%    75%     max
# hotel
# City Hotel    79330.0  105.304465  43.602954  0.00  79.2  99.9  126.0  5400.0
# Resort Hotel  40060.0   94.952930  61.442418 -6.38  50.0  75.0  125.0   508.0

# %% [markdown]
# ### Exercise 7
#
# We observe two unusual values in the summary statistics above -- a negative minimum, and a very high maximum).
# What types of hotels are these?
#
# Locate these observations in the data set and find out the arrival date (year and month) as well as how many people (adults, children, and babies) stayed in the room.
#
# You can investigate the data by showing the data frame to locate these values, but preferably you should identify them in a reproducible way with some code.

# %%
# Find the max
lookup = 5400
# My columns
my_columns  =['hotel','arrival_date_year','arrival_date_month','adults','children','babies','is_canceled','adr']


mask = DF_raw_hotels['adr']==lookup
show(DF_raw_hotels[mask][my_columns])


# Find the min
lookup = -6.38
mask = DF_raw_hotels['adr']==lookup
show(DF_raw_hotels[mask][my_columns])
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4434f796_7f08_428c_893a_b15c711d3e19"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4434f796_7f08_428c_893a_b15c711d3e19:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>hotel</th>\n      <th>arrival_date_year</th>\n      <th>arrival_date_month</th>\n      <th>adults</th>\n      <th>children</th>\n      <th>babies</th>\n      <th>is_canceled</th>\n      <th>adr</th>\n    </tr>\n  </thead></table>", "data_json": "[[48515, \"City Hotel\", 2016, \"March\", 2, 0.0, 0, 1, 5400.0]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5d204319_6628_4351_8c71_d7261f4f3006"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5d204319_6628_4351_8c71_d7261f4f3006:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>hotel</th>\n      <th>arrival_date_year</th>\n      <th>arrival_date_month</th>\n      <th>adults</th>\n      <th>children</th>\n      <th>babies</th>\n      <th>is_canceled</th>\n      <th>adr</th>\n    </tr>\n  </thead></table>", "data_json": "[[14969, \"Resort Hotel\", 2017, \"March\", 2, 0.0, 0, 0, -6.38]]"};
#         new ITable(table, dt_args);
#     });
# </script>
